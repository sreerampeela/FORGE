# %%
import os
import pickle

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from adjustText import adjust_text
from scipy.stats import pearsonr, spearmanr
from sklearn.metrics import r2_score, mean_absolute_error
from matplotlib import rcParams
import re

# === 0. Plot Settings (Matches your reference) ===
rcParams['pdf.fonttype'] = 42 
rcParams['ps.fonttype'] = 42   
rcParams['font.family'] = 'DejaVu Sans'

# %%
pdx_bs = pd.read_csv("/home/nilabjab/cancer_dependency_project_nilabja/cancer_dependency_project/Approach3_Latent_factor/git_repo/Data/pdx_optuna_newScores_01012026.csv")

# %%
pdx_bs.head()
# Out:
#    pdx_id    T5     T10     T15    T20  benefit_score_scaled  benefit_score  \
# 0  X-1156  61.4  202.95  184.80  391.7              0.674761      -0.022499
# 1  X-1172  -0.6   74.00  172.05    NaN              0.387321      -1.137887
# 2  X-1323 -18.6  -18.90   27.60   57.2              0.009016      -2.605868
# 3  X-1442 -10.4   -3.00   13.60    NaN              0.647931      -0.126610
# 4  X-1499  10.6   93.20  302.45    NaN              0.612925      -0.262451
#
#           depmap_cat     pdx_cat
# 0  high_score_depmap  high_score
# 1   low_score_depmap   low_score
# 2   low_score_depmap   low_score
# 3  high_score_depmap  high_score
# 4  high_score_depmap  high_score

# %%
plt.figure(figsize=(6,4))
sns.kdeplot(
    data=pdx_bs,
    x="benefit_score",
    fill=True
)

plt.xlabel("Benefit Score")
plt.ylabel("Density")
plt.title("Density Plot of Benefit Score")
plt.tight_layout()
sns.despine(top=True, right=True)

plt.savefig('/home/nilabjab/cancer_dependency_project_nilabja/cancer_dependency_project/Approach3_Latent_factor/git_repo/Figs/Suppl_figs/pdx_bs_densityplot.pdf', dpi=300)
plt.show()
